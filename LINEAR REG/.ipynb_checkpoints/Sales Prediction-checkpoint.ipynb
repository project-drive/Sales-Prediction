# %%
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt 
import sklearn
from sklearn.model_selection import train_test_split

# %%
#load the data 
og_sales = pd.read_csv("sales.csv")
og_sales.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Fill all NAN with 0
og_sales.fillna(0)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 11   529-56-3974      B   Mandalay        Member    Male
# 12   365-64-0515      A     Yangon        Normal  Female
# 13   252-56-2699      A     Yangon        Normal    Male
# 14   829-34-3910      A     Yangon        Normal  Female
# ...

# %%
#Setting date as Index
og_sales = og_sales.set_index("Date")
og_sales.head()
# Out:
#             Invoice ID Branch       City Customer type  Gender  \
# Date
# 1/5/2019   750-67-8428      A     Yangon        Member  Female
# 3/8/2019   226-31-3081      C  Naypyitaw        Normal  Female
# 3/3/2019   631-41-3108      A     Yangon        Normal    Male
# 1/27/2019  123-19-1176      A     Yangon        Member    Male
# 2/8/2019   373-73-7910      A     Yangon        Normal    Male
#
#                      Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 1/5/2019        Health and beauty       74.69         7  26.1415  548.9715
# 3/8/2019   Electronic accessories       15.28         5   3.8200   80.2200
# 3/3/2019       Home and lifestyle       46.33         7  16.2155  340.5255
# 1/27/2019       Health and beauty       58.22         8  23.2880  489.0480
# 2/8/2019        Sports and travel       86.31         7  30.2085  634.3785
#
#             Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %%
#sorting by date 
sorted_og_sales = og_sales.sort_values(by = 'Date')
sorted_og_sales.head(10)
# Out:
#            Invoice ID Branch       City Customer type  Gender  \
# Date
# 1/1/2019  556-97-7101      C  Naypyitaw        Normal  Female
# 1/1/2019  493-65-6248      C  Naypyitaw        Member  Female
# 1/1/2019  651-88-7328      A     Yangon        Normal  Female
# 1/1/2019  133-14-7229      C  Naypyitaw        Normal    Male
# 1/1/2019  746-04-1077      B   Mandalay        Member  Female
# 1/1/2019  891-01-7034      B   Mandalay        Normal  Female
# 1/1/2019  765-26-6951      A     Yangon        Normal    Male
# 1/1/2019  182-52-7000      A     Yangon        Member  Female
# 1/1/2019  530-90-9855      A     Yangon        Member    Male
# 1/1/2019  416-17-9926      A     Yangon        Member  Female
#
#                     Product line  Unit price  Quantity  Tax 5%    Total  \
# Date
# 1/1/2019  Electronic accessories       63.22         2   6.322  132.762
# 1/1/2019       Sports and travel       36.98        10  18.490  388.290
# ...

# %%
#Extract Features
feature_df = pd.DataFrame(og_sales, columns = ['Invoice ID', 'Product line', 'Quantity', 'Unit price'])
feature_df.rename(columns = {"Invoice ID":"ID", "Product line":"Domain", "Quantity": "Quantity", "Unit price":"Unit_Price"}, inplace = True)
feature_df = feature_df.sort_values(by = 'Date')
feature_df.head(10)
# Out:
#                    ID                  Domain  Quantity  Unit_Price
# Date
# 1/1/2019  556-97-7101  Electronic accessories         2       63.22
# 1/1/2019  493-65-6248       Sports and travel        10       36.98
# 1/1/2019  651-88-7328     Fashion accessories         9       65.74
# 1/1/2019  133-14-7229       Health and beauty         2       62.87
# 1/1/2019  746-04-1077      Food and beverages        10       84.63
# 1/1/2019  891-01-7034  Electronic accessories         6       74.71
# 1/1/2019  765-26-6951       Sports and travel         6       72.61
# 1/1/2019  182-52-7000       Sports and travel         4       27.04
# 1/1/2019  530-90-9855      Home and lifestyle         8       47.59
# 1/1/2019  416-17-9926  Electronic accessories        10       74.22

# %%
#to calculate the gross sale amount 
feature_df['Gross'] = feature_df.Quantity * feature_df.Unit_Price

# %%
feature_df
# Out:
#                     ID                  Domain  Quantity  Unit_Price   Gross
# Date
# 1/1/2019   556-97-7101  Electronic accessories         2       63.22  126.44
# 1/1/2019   493-65-6248       Sports and travel        10       36.98  369.80
# 1/1/2019   651-88-7328     Fashion accessories         9       65.74  591.66
# 1/1/2019   133-14-7229       Health and beauty         2       62.87  125.74
# 1/1/2019   746-04-1077      Food and beverages        10       84.63  846.30
# 1/1/2019   891-01-7034  Electronic accessories         6       74.71  448.26
# 1/1/2019   765-26-6951       Sports and travel         6       72.61  435.66
# 1/1/2019   182-52-7000       Sports and travel         4       27.04  108.16
# 1/1/2019   530-90-9855      Home and lifestyle         8       47.59  380.72
# 1/1/2019   416-17-9926  Electronic accessories        10       74.22  742.20
# 1/1/2019   770-42-8960      Food and beverages         8       21.12  168.96
# ...

# %%
# Splitting Train and Test Data 
# test_ratio = 20 %
train_set, test_set = train_test_split(housing, test_size = 0.2, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ec743141a8b7> in <module>
#       2 # test_ratio = 20 %
#       3 test_ratio = 0.2
# ----> 4 shuffled_indices = np.random.permuatation(len(feature_df))
#       5 test_set_size = int(len(feature_df) * test_ratio)
#       6 test_indices = shuffled_indices[:test_set_size]
#
# AttributeError: module 'numpy.random' has no attribute 'permuatation'
